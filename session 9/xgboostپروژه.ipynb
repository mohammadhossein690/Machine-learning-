# %%
# --- پروژه ۲: Ensemble Methods & Boosting ---

# 1) برگشت به ریشه و کلون ریپو
import os
os.chdir("/content")  # مطمئن شو در روت کولب هستی

# !rm -rf ensemble-methods-and-boosting-examples
# !git clone https://github.com/wins-wang/ensemble-methods-and-boosting-examples.git
# %cd ensemble-methods-and-boosting-examples

# 2) نصب کتابخانه‌های لازم
# !pip install -q numpy pandas scikit-learn matplotlib

print("\n✅ ریپو کلون شد.")
print("📁 نوت‌بوک‌ها داخل پوشه 'notebooks/' هستند, مثلاً:")
print("  - 01_classification_baselines.ipynb")
print("  - 02_tree_based_models_and_bagging.ipynb")
print("و دیتاست‌ها در پوشه 'data/' قرار دارند.")

print("\nاز پنل Files در Colab وارد پوشه notebooks شو و یکی از نوت‌بوک‌ها را باز و اجرا کن.")
# Out:
# Cloning into 'ensemble-methods-and-boosting-examples'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 23 (delta 5), reused 23 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 897.75 KiB | 15.22 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/ensemble-methods-and-boosting-examples
#
# ✅ ریپو کلون شد.
# 📁 نوت‌بوک‌ها داخل پوشه 'notebooks/' هستند, مثلاً:
#   - 01_classification_baselines.ipynb
#   - 02_tree_based_models_and_bagging.ipynb
# و دیتاست‌ها در پوشه 'data/' قرار دارند.
#
# از پنل Files در Colab وارد پوشه notebooks شو و یکی از نوت‌بوک‌ها را باز و اجرا کن.

# %%
# اجرای خودکار نوت‌بوک دوم (Tree-based + Bagging)
# !pip install -q nbconvert

# !jupyter nbconvert --to notebook --execute notebooks/02_tree_based_models_and_bagging.ipynb \
    --output output_02_tree_based_models_and_bagging.ipynb

print("\n✅ نوت‌بوک 02 به صورت خودکار اجرا شد و خروجی در فایل 'output_02_tree_based_models_and_bagging.ipynb' ذخیره شد.")
# Out:
# [NbConvertApp] Converting notebook notebooks/02_tree_based_models_and_bagging.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
